# %% [markdown]
# # Defining a custom model of 2 dense layers

# %%
import tensorflow as tf

class Model(tf.keras.Model):
  def __init__(self, units):
    super().__init__()
    self.dense1 = tf.keras.layers.Dense(units=units,
                                        activation=tf.nn.relu,
                                        kernel_initializer=tf.random.normal,
                                        bias_initializer=tf.random.normal)
    self.dense2 = tf.keras.layers.Dense(1)

  def call(self, x, training=True):
    # For Keras layers/models, implement `call` instead of `__call__`.
    x = x[:, tf.newaxis]
    x = self.dense1(x)
    x = self.dense2(x)
    return tf.squeeze(x, axis=1)

# %%
my_model =Model(128)

# %% [markdown]
# # **Untrained Prediction**

# %%
from matplotlib import pyplot as plt

x = tf.linspace(-5, 5, 201)

# tf.cast is to typasting of a tensor from one data format to other..
x = tf.cast(x, tf.float32)

def func(x):
    y = x**2 + 2*x - 5
    return y


# T is a random tensor of 201 elements
# shape = no. of elements
T = tf.random.normal(shape=[201])

y = func(x) + T 


plt.plot(x.numpy(), y.numpy(), '.', label='data')
plt.plot(x, func(x),  label='Ground truth')
plt.plot(x, my_model(x), label='Untrained predictions')
plt.title('Before training')
plt.legend();

# %% [markdown]
# # **Basic Training Loops**

# %%
variables = my_model.variables
# print(variables)

opt = tf.optimizers.Adam(learning_rate = 0.001)

for step in range(500):
    with tf.GradientTape() as tape:
        pred = my_model(x)
        error = (y-pred)**2
        mean_error = tf.reduce_mean(error)
    gradient = tape.gradient(mean_error, variables)
    opt.apply_gradients(zip(gradient, variables))

    if step % 100 == 0:
        print(f'Mean squared error: {mean_error.numpy():0.3f}')
    
    # print(pred)
# Out:
# Mean squared error: 82.739
# Mean squared error: 12.191
# Mean squared error: 3.976
# Mean squared error: 2.671
# Mean squared error: 2.317

# %% [markdown]
# # **Plotting after training**

# %%
plt.plot(x.numpy(), y.numpy(), '.', label="Data")
plt.plot(x.numpy(), func(x), '.', label="Ground Truth")
plt.plot(x.numpy(), my_model(x), '.', label="Trained Predictions")
plt.title("Predictions after training")
plt.legend();

# %% [markdown]
# # **Training using model.fit**

# %%
new_model = Model(64)

new_model.compile(
    loss=tf.keras.losses.MSE,
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
)

history = new_model.fit(
    x,
    y,
    epochs = 100,
    batch_size = 32,
    verbose=1
)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 1ms/step - loss: 73.1298
# Epoch 2/100
# 7/7 [==============================] - 0s 1ms/step - loss: 39.7388
# Epoch 3/100
# 7/7 [==============================] - 0s 2ms/step - loss: 30.8426
# Epoch 4/100
# 7/7 [==============================] - 0s 1ms/step - loss: 24.4198
# Epoch 5/100
# 7/7 [==============================] - 0s 2ms/step - loss: 18.2278
# Epoch 6/100
# 7/7 [==============================] - 0s 1ms/step - loss: 14.2326
# Epoch 7/100
# 7/7 [==============================] - 0s 2ms/step - loss: 10.4328
# Epoch 8/100
# 7/7 [==============================] - 0s 1ms/step - loss: 7.4307
# Epoch 9/100
# 7/7 [==============================] - 0s 2ms/step - loss: 5.7134
# Epoch 10/100
# 7/7 [==============================] - 0s 2ms/step - loss: 4.2538
# Epoch 11/100
# 7/7 [==============================] - 0s 1ms/step - loss: 3.6570
# Epoch 12/100
# 7/7 [==============================] - 0s 2ms/step - loss: 3.2781
# Epoch 13/100
# 7/7 [==============================] - 0s 1ms/step - loss: 3.1103
# Epoch 14/100
# 7/7 [==============================] - 0s 2ms/step - loss: 3.0137
# Epoch 15/100
# 7/7 [==============================] - 0s 1ms/step - loss: 2.8881
# Epoch 16/100
# 7/7 [==============================] - 0s 1ms/step - loss: 2.9209
# Epoch 17/100
# 7/7 [==============================] - 0s 1ms/step - loss: 2.7579
# Epoch 18/100
# 7/7 [==============================] - 0s 1ms/step - loss: 2.8408
# Epoch 19/100
# 7/7 [==============================] - 0s 1ms/step - loss: 2.6554
# Epoch 20/100
# 7/7 [==============================] - 0s 2ms/step - loss: 2.5747
# Epoch 21/100
# 7/7 [==============================] - 0s 2ms/step - loss: 2.4337
# Epoch 22/100
# 7/7 [==============================] - 0s 1000us/step - loss: 2.3305
# Epoch 23/100
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3484
# Epoch 24/100
# 7/7 [==============================] - 0s 1ms/step - loss: 2.2636
# Epoch 25/100
# 7/7 [==============================] - 0s 1ms/step - loss: 2.1328
# Epoch 26/100
# 7/7 [==============================] - 0s 1ms/step - loss: 2.0966
# Epoch 27/100
# 7/7 [==============================] - 0s 1ms/step - loss: 2.1074
# Epoch 28/100
# 7/7 [==============================] - 0s 1ms/step - loss: 2.0265
# Epoch 29/100
# 7/7 [==============================] - 0s 1ms/step - loss: 2.0456
# Epoch 30/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.9491
# Epoch 31/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.8177
# Epoch 32/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.9176
# Epoch 33/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.8817
# Epoch 34/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.9444
# Epoch 35/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.7196
# Epoch 36/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.6851
# Epoch 37/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.6657
# Epoch 38/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.6542
# Epoch 39/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.6346
# Epoch 40/100
# 7/7 [==============================] - 0s 1000us/step - loss: 1.5549
# Epoch 41/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.5252
# Epoch 42/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.6518
# Epoch 43/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.5373
# Epoch 44/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.5006
# Epoch 45/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4620
# Epoch 46/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4162
# Epoch 47/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.4480
# Epoch 48/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3469
# Epoch 49/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3895
# Epoch 50/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.4118
# Epoch 51/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3123
# Epoch 52/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3377
# Epoch 53/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2888
# Epoch 54/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2990
# Epoch 55/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2829
# Epoch 56/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2839
# Epoch 57/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2532
# Epoch 58/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3479
# Epoch 59/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2541
# Epoch 60/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2949
# Epoch 61/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2754
# Epoch 62/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.3057
# Epoch 63/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2405
# Epoch 64/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4752
# Epoch 65/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.4891
# Epoch 66/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2644
# Epoch 67/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2096
# Epoch 68/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1877
# Epoch 69/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2045
# Epoch 70/100
# 7/7 [==============================] - ETA: 0s - loss: 1.032 - 0s 2ms/step - loss: 1.1987
# Epoch 71/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2355
# Epoch 72/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1617
# Epoch 73/100
# 7/7 [==============================] - ETA: 0s - loss: 1.257 - 0s 1ms/step - loss: 1.1570
# Epoch 74/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1590
# Epoch 75/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1478
# Epoch 76/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1490
# Epoch 77/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2480
# Epoch 78/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1571
# Epoch 79/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1082
# Epoch 80/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1397
# Epoch 81/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1283
# Epoch 82/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1750
# Epoch 83/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2016
# Epoch 84/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3659
# Epoch 85/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1578
# Epoch 86/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1138
# Epoch 87/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2279
# Epoch 88/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1185
# Epoch 89/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1085
# Epoch 90/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1141
# Epoch 91/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2922
# Epoch 92/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1989
# Epoch 93/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.2602
# Epoch 94/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0503
# Epoch 95/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1615
# Epoch 96/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.0885
# Epoch 97/100
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0705
# Epoch 98/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.0796
# Epoch 99/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.0800
# Epoch 100/100
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1409

# %% [markdown]
# # **Saving Model**

# %%
name = "new_model"
new_model.save("./Saved Models/" + name)
# Out:
# INFO:tensorflow:Assets written to: ./Saved Models/new_model\assets

# %% [markdown]
# # **Plotting losses and accuracy**

# %%
plt.plot(history.history['loss'])
plt.xlabel("Epochs")
plt.ylabel("Loss [Mean Squared Error]")
plt.title("Model training progress")
# Out:
# Text(0.5, 1.0, 'Model training progress')
